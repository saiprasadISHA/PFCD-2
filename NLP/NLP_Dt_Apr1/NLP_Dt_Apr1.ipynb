# %%
from textblob import TextBlob
text='Today is a beautiful day. Tomorrow it looks like a bad weather'
blob=TextBlob(text)
blob

# %%
blob.sentences

# %%
blob.words

# %%
blob.tags

# %%
blob.noun_phrases

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.85, subjectivity=1.0)

# %%
# %precision 3

# %%
blob.sentiment.polarity

# %%
# !pip install nltk

# %%
from textblob import Word
index=Word('index')
index.pluralize()
# Out:
# 'indices'

# %%
cacti=Word('cacti')
cacti.singularize()
# Out:
# 'cactus'

# %%
animals=TextBlob('dog cat fish bull').words
animals.pluralize()
# Out:
# WordList(['dogs', 'cats', 'fish', 'bulls'])

# %%
word=Word('strawberries')
word.stem()
# Out:
# 'strawberri'

# %%
import nltk

# %%
# Word frequencies
from pathlib import Path
from textblob import TextBlob

blob=TextBlob(Path('RomeoandJuliet.txt').read_text())
# blob.wordcount()
print(len(blob.words))

# %%
from nltk.corpus import stopwords

# %%
stops=stopwords.words('english')

# %%
from textblob import TextBlob
blob=TextBlob('Today is a beautiful day')
[word for word in blob.words if word not in stops]
# Out:
# ['Today', 'beautiful', 'day']

# %%
from textblob import TextBlob
text='Today is a beautiful day. Tomorrow it looks like a bad weather'
blob=TextBlob(text)
# blob.ngrams()

# %%
blob.ngrams(5)
# Out:
# [WordList(['Today', 'is', 'a', 'beautiful', 'day']),
#  WordList(['is', 'a', 'beautiful', 'day', 'Tomorrow']),
#  WordList(['a', 'beautiful', 'day', 'Tomorrow', 'it']),
#  WordList(['beautiful', 'day', 'Tomorrow', 'it', 'looks']),
#  WordList(['day', 'Tomorrow', 'it', 'looks', 'like']),
#  WordList(['Tomorrow', 'it', 'looks', 'like', 'a']),
#  WordList(['it', 'looks', 'like', 'a', 'bad']),
#  WordList(['looks', 'like', 'a', 'bad', 'weather'])]

# %%
# Visualize word frequencies with bar chart and word closed
# with the help of bar chart

from pathlib import Path
from textblob import TextBlob
blob=TextBlob(Path('RomeoandJuliet.txt').read_text())

from nltk.corpus import stopwords
stop_words=stopwords.words('english')
items=blob.word_counts.items()
# print(items)
items=[item for item in items if item[0] not in stop_words]
from operator import itemgetter
sorted_items=sorted(items, key=lambda x:x[1], reverse=True)
# sorted_items=sorted(items, key=itemgetter(1), reverse=True)

top20=sorted_items[1:21]
# print(top20)
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as pl
df=pd.DataFrame(top20, columns=['word','count'])
colors=mat.rcParams['axes.prop_cycle'].by_key()['color']
axes=df.plot.bar(x='word', y='count',legend=False,color=colors)
pl.gcf().tight_layout()

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/1f/6d/483e6c721cc2a1d255d3fce85116863c32f2bc1fb4c5e0da2d0ca7ab19c3/wordcloud-1.9.6-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 8.3 MB/s eta 0:00:00 0:00:01
# ...

# %%
# with the help of Word clouds
from pathlib import Path
from textblob import TextBlob
text=TextBlob(Path('RomeoandJuliet.txt').read_text())
text=text.raw
import imageio
import imageio.v2 as imageio
mask_image=imageio.imread('mask_heart.png')
from wordcloud import WordCloud
# wordcloud=WordCloud(width=800, height=400,background_color='white')
wordcloud=WordCloud(colormap='prism', mask=mask_image, background_color='white')
wordcloud=wordcloud.generate(text)
# wordcloud=WordCloud.generate(text)
wordcloud= wordcloud.to_file('mask_heart.png')
get_ipython().run_line_magic('matplotlib','')
import matplotlib.pyplot as pl
pl.figure(figsize=(10,10))
pl.imshow(wordcloud)
# Out:
# Using matplotlib backend: QtAgg
# qt.glx: qglx_findConfig: Failed to finding matching FBConfig for QSurfaceFormat(version 2.0, options QFlags<QSurfaceFormat::FormatOption>(), depthBufferSize -1, redBufferSize 1, greenBufferSize 1, blueBufferSize 1, alphaBufferSize -1, stencilBufferSize -1, samples -1, swapBehavior QSurfaceFormat::SingleBuffer, swapInterval 1, colorSpace QSurfaceFormat::DefaultColorSpace, profile  QSurfaceFormat::NoProfile)
# No XVisualInfo for format QSurfaceFormat(version 2.0, options QFlags<QSurfaceFormat::FormatOption>(), depthBufferSize -1, redBufferSize 1, greenBufferSize 1, blueBufferSize 1, alphaBufferSize -1, stencilBufferSize -1, samples -1, swapBehavior QSurfaceFormat::SingleBuffer, swapInterval 1, colorSpace QSurfaceFormat::DefaultColorSpace, profile  QSurfaceFormat::NoProfile)
# Falling back to using screens root_visual.

# %%
# !pip install spaCy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.9 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
# ...
#         Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/9d/76/f789f7a86709c6b087c5a2f52f911838cad707cc613162401badc665acfe/setuptools-82.0.1-py3-none-any.whl.metadata
# ...
#         Obtaining dependency information for cython<4.0,>=3.0 from https://files.pythonhosted.org/packages/c3/1a/416cc55d567f94b1249a0e007951115e2f7d296eabc345276c3859af76c9/cython-3.2.4-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
# ...
